# %% [markdown]
# ## Pre-pro

# %%
# Make sure to run with python 3.7
# sudo apt-get install build-essential libasound2-dev libjack-dev portaudio19-dev
# sudo apt-get install libsndfile1
# !pip install magenta[beam]
# !pip install music21
# !pip install python-snappy
# !pip install -e './tensor2tensor'

# Make sure GPU is set up within the conda environment
# !conda install cudatoolkit
# !conda install cudnn
# !export LD_LIBRARY_PATH="$CONDA_PREFIX/lib"
# Out:
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Requirement already satisfied: magenta[beam] in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (2.1.4)
# Requirement already satisfied: python-rtmidi==1.1.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.1.2)
# Requirement already satisfied: numba==0.49.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.49.1)
# Requirement already satisfied: dm-sonnet==2.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (2.0.0)
# Requirement already satisfied: numpy==1.21.6 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.21.6)
# Requirement already satisfied: scipy==1.7.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.7.3)
# Requirement already satisfied: note-seq==0.0.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.0.3)
# Requirement already satisfied: mir-eval==0.7 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.7)
# Requirement already satisfied: Pillow==9.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (9.2.0)
# Requirement already satisfied: sk-video==1.1.10 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.1.10)
# Requirement already satisfied: librosa==0.7.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.7.2)
# Requirement already satisfied: sox==1.4.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.4.1)
# Requirement already satisfied: pretty-midi==0.2.9 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.2.9)
# Requirement already satisfied: mido==1.2.6 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.2.6)
# Requirement already satisfied: tensorflow-datasets==4.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (4.6.0)
# Requirement already satisfied: tensorflow==2.9.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (2.9.1)
# Requirement already satisfied: imageio==2.20.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (2.20.0)
# Requirement already satisfied: wheel==0.37.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.37.1)
# Requirement already satisfied: matplotlib==3.5.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (3.5.2)
# Requirement already satisfied: tf-slim==1.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.1.0)
# Requirement already satisfied: six==1.16.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.16.0)
# Requirement already satisfied: pygtrie==2.5.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (2.5.0)
# Collecting tensorflow-probability==0.17.0
#   Using cached tensorflow_probability-0.17.0-py2.py3-none-any.whl (6.5 MB)
# Requirement already satisfied: scikit-image==0.19.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (0.19.3)
# Requirement already satisfied: absl-py==1.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (1.2.0)
# Requirement already satisfied: apache-beam[gcp]==2.40.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from magenta[beam]) (2.40.0)
# Requirement already satisfied: pytz>=2018.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2022.7)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.7.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (4.4.0)
# Requirement already satisfied: orjson<4.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (3.8.3)
# Requirement already satisfied: grpcio<2,>=1.33.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.51.1)
# Requirement already satisfied: cloudpickle<3,>=2.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.8.2)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (7.0.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.22.1)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (3.13.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.4.2)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.7)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (0.3.1.1)
# Requirement already satisfied: protobuf<4,>=3.12.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (3.19.6)
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (0.20.4)
# Requirement already satisfied: google-cloud-core<2,>=0.28.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.7.3)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.6.0)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (0.1.0)
# Requirement already satisfied: grpcio-gcp<1,>=0.2.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (0.2.2)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.3.2)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (0.5.31)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.6.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.17.0)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.35.0)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (3.10.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.13.11)
# Requirement already satisfied: google-cloud-datastore<2,>=1.8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.15.5)
# Requirement already satisfied: google-cloud-bigquery<3,>=1.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (2.34.4)
# Requirement already satisfied: google-cloud-spanner<2,>=1.13.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.19.3)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.7.3)
# Requirement already satisfied: google-cloud-recommendations-ai<=0.2.0,>=0.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (0.2.0)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.16.3)
# Requirement already satisfied: cachetools<5,>=3.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (4.2.4)
# Requirement already satisfied: google-cloud-vision<2,>=0.38.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from apache-beam[gcp]==2.40.0->magenta[beam]) (1.0.2)
# Requirement already satisfied: wrapt>=1.11.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dm-sonnet==2.0.0->magenta[beam]) (1.14.1)
# Requirement already satisfied: dm-tree>=0.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dm-sonnet==2.0.0->magenta[beam]) (0.1.8)
# Requirement already satisfied: tabulate>=0.7.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dm-sonnet==2.0.0->magenta[beam]) (0.9.0)
# Requirement already satisfied: resampy>=0.2.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from librosa==0.7.2->magenta[beam]) (0.3.1)
# Requirement already satisfied: joblib>=0.12 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from librosa==0.7.2->magenta[beam]) (1.2.0)
# Requirement already satisfied: soundfile>=0.9.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from librosa==0.7.2->magenta[beam]) (0.11.0)
# Requirement already satisfied: audioread>=2.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from librosa==0.7.2->magenta[beam]) (3.0.0)
# Requirement already satisfied: decorator>=3.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from librosa==0.7.2->magenta[beam]) (5.1.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from librosa==0.7.2->magenta[beam]) (1.0.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib==3.5.2->magenta[beam]) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib==3.5.2->magenta[beam]) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib==3.5.2->magenta[beam]) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib==3.5.2->magenta[beam]) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib==3.5.2->magenta[beam]) (21.3)
# Requirement already satisfied: future in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from mir-eval==0.7->magenta[beam]) (0.18.2)
# Requirement already satisfied: IPython in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from note-seq==0.0.3->magenta[beam]) (7.34.0)
# Requirement already satisfied: intervaltree>=2.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from note-seq==0.0.3->magenta[beam]) (3.1.0)
# Requirement already satisfied: bokeh>=0.12.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from note-seq==0.0.3->magenta[beam]) (2.4.3)
# Requirement already satisfied: attrs in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from note-seq==0.0.3->magenta[beam]) (22.2.0)
# Requirement already satisfied: pydub in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from note-seq==0.0.3->magenta[beam]) (0.25.1)
# Requirement already satisfied: pandas>=0.18.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from note-seq==0.0.3->magenta[beam]) (1.3.5)
# Requirement already satisfied: setuptools in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from numba==0.49.1->magenta[beam]) (65.5.0)
# Requirement already satisfied: llvmlite<=0.33.0.dev0,>=0.31.0.dev0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from numba==0.49.1->magenta[beam]) (0.32.1)
# Requirement already satisfied: networkx>=2.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from scikit-image==0.19.3->magenta[beam]) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from scikit-image==0.19.3->magenta[beam]) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from scikit-image==0.19.3->magenta[beam]) (2021.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (0.2.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (14.0.6)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (0.29.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (1.12)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (2.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow==2.9.1->magenta[beam]) (3.7.0)
# Requirement already satisfied: toml in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets==4.6.0->magenta[beam]) (0.10.2)
# Requirement already satisfied: promise in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets==4.6.0->magenta[beam]) (2.3)
# Requirement already satisfied: tensorflow-metadata in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets==4.6.0->magenta[beam]) (1.12.0)
# Requirement already satisfied: tqdm in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets==4.6.0->magenta[beam]) (4.64.1)
# Requirement already satisfied: etils[epath] in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets==4.6.0->magenta[beam]) (0.9.0)
# Requirement already satisfied: importlib-resources in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets==4.6.0->magenta[beam]) (5.10.2)
# Requirement already satisfied: Jinja2>=2.9 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from bokeh>=0.12.0->note-seq==0.0.3->magenta[beam]) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from bokeh>=0.12.0->note-seq==0.0.3->magenta[beam]) (6.2)
# Requirement already satisfied: PyYAML>=3.10 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from bokeh>=0.12.0->note-seq==0.0.3->magenta[beam]) (6.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]==2.40.0->magenta[beam]) (4.1.3)
# Requirement already satisfied: fasteners>=0.14 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]==2.40.0->magenta[beam]) (0.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]==2.40.0->magenta[beam]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]==2.40.0->magenta[beam]) (4.9)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-cloud-bigquery<3,>=1.6.0->apache-beam[gcp]==2.40.0->magenta[beam]) (1.34.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-cloud-bigquery<3,>=1.6.0->apache-beam[gcp]==2.40.0->magenta[beam]) (2.4.0)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-cloud-bigtable<2,>=0.31.1->apache-beam[gcp]==2.40.0->magenta[beam]) (0.12.4)
# Requirement already satisfied: grpcio-status>=1.16.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]==2.40.0->magenta[beam]) (1.48.2)
# Requirement already satisfied: overrides<7.0.0,>=6.0.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]==2.40.0->magenta[beam]) (6.5.0)
# Requirement already satisfied: docopt in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]==2.40.0->magenta[beam]) (0.6.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from intervaltree>=2.1.0->note-seq==0.0.3->magenta[beam]) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]==2.40.0->magenta[beam]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]==2.40.0->magenta[beam]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]==2.40.0->magenta[beam]) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]==2.40.0->magenta[beam]) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.7.2->magenta[beam]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from soundfile>=0.9.0->librosa==0.7.2->magenta[beam]) (1.15.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (2.2.2)
# Requirement already satisfied: zipp in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from etils[epath]->tensorflow-datasets==4.6.0->magenta[beam]) (3.11.0)
# Requirement already satisfied: pexpect>4.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (0.18.2)
# Requirement already satisfied: pickleshare in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (0.7.5)
# Requirement already satisfied: backcall in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (5.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (3.0.36)
# Requirement already satisfied: pygments in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (2.13.0)
# Requirement already satisfied: matplotlib-inline in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from IPython->note-seq==0.0.3->magenta[beam]) (0.1.6)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-metadata->tensorflow-datasets==4.6.0->magenta[beam]) (1.57.0)
# Requirement already satisfied: pycparser in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa==0.7.2->magenta[beam]) (2.21)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<3,>=1.6.0->apache-beam[gcp]==2.40.0->magenta[beam]) (1.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from jedi>=0.16->IPython->note-seq==0.0.3->magenta[beam]) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from Jinja2>=2.9->bokeh>=0.12.0->note-seq==0.0.3->magenta[beam]) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (5.2.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]==2.40.0->magenta[beam]) (0.4.8)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pexpect>4.3->IPython->note-seq==0.0.3->magenta[beam]) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->note-seq==0.0.3->magenta[beam]) (0.2.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->magenta[beam]) (3.2.2)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Installing collected packages: tensorflow-probability
#   Attempting uninstall: tensorflow-probability
#     WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
#     Found existing installation: tensorflow-probability 0.7.0
#     Uninstalling tensorflow-probability-0.7.0:
#       Successfully uninstalled tensorflow-probability-0.7.0
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensor2tensor 1.15.7 requires tensorflow-probability==0.7.0, but you have tensorflow-probability 0.17.0 which is incompatible.
# Successfully installed tensorflow-probability-0.17.0
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Requirement already satisfied: music21 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (7.3.3)
# Requirement already satisfied: jsonpickle in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (3.0.1)
# Requirement already satisfied: webcolors>=1.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (1.12)
# Requirement already satisfied: chardet in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (5.1.0)
# Requirement already satisfied: more-itertools in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (9.0.0)
# Requirement already satisfied: numpy in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (1.21.6)
# Requirement already satisfied: joblib in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (1.2.0)
# Requirement already satisfied: matplotlib in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from music21) (3.5.2)
# Requirement already satisfied: importlib-metadata in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from jsonpickle->music21) (5.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->music21) (1.4.4)
# Requirement already satisfied: typing-extensions in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->music21) (4.4.0)
# Requirement already satisfied: six>=1.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from importlib-metadata->jsonpickle->music21) (3.11.0)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Requirement already satisfied: python-snappy in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (0.6.1)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Obtaining file:///mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor
#   Preparing metadata (setup.py) ... done
#   WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Requirement already satisfied: absl-py in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (1.2.0)
# Requirement already satisfied: bz2file in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.98)
# Requirement already satisfied: dopamine-rl in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (3.2.1)
# Requirement already satisfied: flask in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (2.2.2)
# Requirement already satisfied: future in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.18.2)
# Requirement already satisfied: gevent in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (22.10.2)
# Requirement already satisfied: gin-config in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.5.0)
# Requirement already satisfied: google-api-python-client in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (2.70.0)
# Requirement already satisfied: gunicorn in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (20.1.0)
# Requirement already satisfied: gym in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.26.2)
# Requirement already satisfied: h5py in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (3.7.0)
# Requirement already satisfied: kfac in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.2.0)
# Requirement already satisfied: mesh-tensorflow in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.1.21)
# Requirement already satisfied: numpy in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (1.21.6)
# Requirement already satisfied: oauth2client in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (4.1.3)
# Requirement already satisfied: opencv-python in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (4.7.0.68)
# Requirement already satisfied: Pillow in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (9.2.0)
# Requirement already satisfied: pypng in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.20220715.0)
# Requirement already satisfied: requests in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (2.28.1)
# Requirement already satisfied: scipy in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (1.7.3)
# Requirement already satisfied: six>=1.12.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (1.16.0)
# Requirement already satisfied: sympy in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (1.10.1)
# Requirement already satisfied: tensorflow-addons in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (0.19.0)
# Requirement already satisfied: tensorflow-datasets in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (4.6.0)
# Requirement already satisfied: tensorflow-gan in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (2.1.0)
# Collecting tensorflow-probability==0.7.0
#   Using cached tensorflow_probability-0.7.0-py2.py3-none-any.whl (981 kB)
# Requirement already satisfied: tf_slim in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (1.1.0)
# Requirement already satisfied: tqdm in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensor2tensor==1.15.7) (4.64.1)
# Requirement already satisfied: decorator in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-probability==0.7.0->tensor2tensor==1.15.7) (5.1.1)
# Requirement already satisfied: cloudpickle>=0.6.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-probability==0.7.0->tensor2tensor==1.15.7) (2.2.0)
# Requirement already satisfied: jax>=0.1.72 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dopamine-rl->tensor2tensor==1.15.7) (0.3.25)
# Requirement already satisfied: jaxlib>=0.1.51 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dopamine-rl->tensor2tensor==1.15.7) (0.3.25)
# Requirement already satisfied: pygame>=1.9.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dopamine-rl->tensor2tensor==1.15.7) (2.1.2)
# Requirement already satisfied: pandas>=0.24.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dopamine-rl->tensor2tensor==1.15.7) (1.3.5)
# Requirement already satisfied: tensorflow>=2.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dopamine-rl->tensor2tensor==1.15.7) (2.9.1)
# Requirement already satisfied: flax>=0.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from dopamine-rl->tensor2tensor==1.15.7) (0.6.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flask->tensor2tensor==1.15.7) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flask->tensor2tensor==1.15.7) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flask->tensor2tensor==1.15.7) (3.1.2)
# Requirement already satisfied: click>=8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flask->tensor2tensor==1.15.7) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flask->tensor2tensor==1.15.7) (5.2.0)
# Requirement already satisfied: zope.event in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from gevent->tensor2tensor==1.15.7) (4.6)
# Requirement already satisfied: zope.interface in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from gevent->tensor2tensor==1.15.7) (5.5.2)
# Requirement already satisfied: greenlet>=2.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from gevent->tensor2tensor==1.15.7) (2.0.1)
# Requirement already satisfied: setuptools in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from gevent->tensor2tensor==1.15.7) (65.5.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-api-python-client->tensor2tensor==1.15.7) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-api-python-client->tensor2tensor==1.15.7) (0.20.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-api-python-client->tensor2tensor==1.15.7) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-api-python-client->tensor2tensor==1.15.7) (1.34.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-api-python-client->tensor2tensor==1.15.7) (0.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from gym->tensor2tensor==1.15.7) (0.0.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from oauth2client->tensor2tensor==1.15.7) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from oauth2client->tensor2tensor==1.15.7) (4.9)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from oauth2client->tensor2tensor==1.15.7) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests->tensor2tensor==1.15.7) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests->tensor2tensor==1.15.7) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests->tensor2tensor==1.15.7) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests->tensor2tensor==1.15.7) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from sympy->tensor2tensor==1.15.7) (1.2.1)
# Requirement already satisfied: packaging in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-addons->tensor2tensor==1.15.7) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-addons->tensor2tensor==1.15.7) (2.13.3)
# Requirement already satisfied: toml in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (0.10.2)
# Requirement already satisfied: typing-extensions in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (4.4.0)
# Requirement already satisfied: promise in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (2.3)
# Requirement already satisfied: etils[epath] in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (0.9.0)
# Requirement already satisfied: termcolor in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (2.1.1)
# Requirement already satisfied: tensorflow-metadata in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (1.12.0)
# Requirement already satisfied: dill in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (0.3.1.1)
# Requirement already satisfied: protobuf>=3.12.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (3.19.6)
# Requirement already satisfied: importlib-resources in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-datasets->tensor2tensor==1.15.7) (5.10.2)
# Requirement already satisfied: tensorflow-hub>=0.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow-gan->tensor2tensor==1.15.7) (0.12.0)
# Requirement already satisfied: matplotlib in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (3.5.2)
# Requirement already satisfied: rich>=11.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (13.0.0)
# Requirement already satisfied: tensorstore in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.1.28)
# Requirement already satisfied: orbax in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.0.23)
# Requirement already satisfied: optax in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.1.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (6.0)
# Requirement already satisfied: msgpack in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client->tensor2tensor==1.15.7) (1.57.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client->tensor2tensor==1.15.7) (4.2.4)
# Requirement already satisfied: ale-py~=0.8.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from gym->tensor2tensor==1.15.7) (0.8.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->tensor2tensor==1.15.7) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from importlib-metadata>=3.6.0->flask->tensor2tensor==1.15.7) (3.11.0)
# Requirement already satisfied: opt-einsum in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from jax>=0.1.72->dopamine-rl->tensor2tensor==1.15.7) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from Jinja2>=3.0->flask->tensor2tensor==1.15.7) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pandas>=0.24.2->dopamine-rl->tensor2tensor==1.15.7) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pandas>=0.24.2->dopamine-rl->tensor2tensor==1.15.7) (2022.7)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.29.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.6.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.12)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (2.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.51.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (2.9.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.37.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from rich>=11.1->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from rich>=11.1->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.9.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.4.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from matplotlib->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.11.0)
# Requirement already satisfied: chex>=0.1.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from optax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.1.5)
# Requirement already satisfied: pytest in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (7.2.0)
# Requirement already satisfied: cached_property in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.5.2)
# Requirement already satisfied: dm-tree>=0.1.5 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from chex>=0.1.5->optax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from chex>=0.1.5->optax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (0.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.3.1)
# Requirement already satisfied: tomli>=1.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pytest->orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (2.0.1)
# Requirement already satisfied: iniconfig in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pytest->orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.1.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pytest->orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pytest->orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (22.2.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from pytest->orbax->flax>=0.2.0->dopamine-rl->tensor2tensor==1.15.7) (1.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.2.0->dopamine-rl->tensor2tensor==1.15.7) (3.2.2)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# Installing collected packages: tensorflow-probability, tensor2tensor
#   Attempting uninstall: tensorflow-probability
#     WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
#     Found existing installation: tensorflow-probability 0.17.0
#     Uninstalling tensorflow-probability-0.17.0:
#       Successfully uninstalled tensorflow-probability-0.17.0
#   Attempting uninstall: tensor2tensor
#     WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
#     Found existing installation: tensor2tensor 1.15.7
#     Uninstalling tensor2tensor-1.15.7:
#       Successfully uninstalled tensor2tensor-1.15.7
#   Running setup.py develop for tensor2tensor
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# magenta 2.1.4 requires tensorflow-probability==0.17.0, but you have tensorflow-probability 0.7.0 which is incompatible.
# Successfully installed tensor2tensor-1.15.7 tensorflow-probability-0.7.0
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-probability (/home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages)
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
import magenta
import music21
import glob
import os
import sys

# Append the submodule tensor2tensor to the Python path so that it is used rather than the pip installed version
sys.path.append(os.path.realpath('./tensor2tensor'))
# Out:
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
data_dir = './MagentaMusicTransformerData'

# %%
for midi_file in glob.glob(data_dir + "/*.mid"):
    print(midi_file)
    try:
        midi = music21.converter.parse(midi_file).flatten()
        key = midi.analyze('key')
        if(key.mode == 'major'):
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('C'))
        elif(key.mode == 'minor'):
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('A'))
        midi = midi.transpose(i)
        newKey = midi.analyze('key')
        print("Tranposed from: " + str(key) + " to " + str(newKey))
        midi.write('midi', fp=midi_file)
    except Exception as e:
        print("Transposing midi failed: " + str(e))
        continue;
# Out:
# ./MagentaMusicTransformerData/01 5-HTP GP.mid
# Tranposed from: B- major to C major
# ./MagentaMusicTransformerData/01 Touch and Go GP.mid
# Tranposed from: A major to C major
# ./MagentaMusicTransformerData/02 Impulsively Responsible GP.mid
# Tranposed from: D major to C major
# ./MagentaMusicTransformerData/02 Vantablack GP.mid
# Tranposed from: D major to C major
# ./MagentaMusicTransformerData/03 A Different Light GP.mid
# Tranposed from: b minor to a minor
# ./MagentaMusicTransformerData/03 Luna[r]tic GP.mid
# Tranposed from: D major to C major
# ./MagentaMusicTransformerData/04 By Far and Away GP.mid
# Tranposed from: E major to C major
# ./MagentaMusicTransformerData/04 Lock & Key GP.mid
# Tranposed from: A major to C major
# ./MagentaMusicTransformerData/05 Belvedere GP.mid
# Tranposed from: e minor to a minor
# ./MagentaMusicTransformerData/05 Signal Hill GP.mid
# Tranposed from: D major to C major
# ./MagentaMusicTransformerData/06 Rubicon Artist GP.mid
# Tranposed from: A major to C major
# ./MagentaMusicTransformerData/06 String Theory GP.mid
# Tranposed from: G major to C major
# ./MagentaMusicTransformerData/07 D.O.S.E GP.mid
# Tranposed from: B- major to C major
# ./MagentaMusicTransformerData/07 The Waterfront GP.mid
# Tranposed from: A major to C major
# ./MagentaMusicTransformerData/08 Earthing GP.mid
# Tranposed from: D major to C major
# ./MagentaMusicTransformerData/08 Leave No Stone GP.mid
# Tranposed from: E major to C major
# ./MagentaMusicTransformerData/1. I'm Awake GP.mid
# Tranposed from: e minor to a minor
# ./MagentaMusicTransformerData/2. Sure Shot GP.mid
# Tranposed from: f# minor to a minor
# ./MagentaMusicTransformerData/3. Fable GP.mid
# Tranposed from: A major to C major
# ./MagentaMusicTransformerData/4. Sweet Tooth GP.mid
# Tranposed from: d minor to a minor
# ./MagentaMusicTransformerData/5. Black Box GP.mid
# Tranposed from: f# minor to a minor
# ./MagentaMusicTransformerData/6. Slight of Hand GP.mid
# Tranposed from: b minor to a minor
# ./MagentaMusicTransformerData/7. Meridian GP.mid
# Tranposed from: E major to C major
# ./MagentaMusicTransformerData/8. Libra GP.mid
# Tranposed from: F major to C major

# %%
# !t2t_datagen \
--data_dir='./MagentaMusicTransformerData' \
--problem=score2perf_maestro_language_uncropped_aug \
--alsologtostderr
# Out:
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/gym/utils/passive_env_checker.py:32: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (3, 3)
#   "A Box observation space has an unconventional shape (neither an image, nor a 1D vector). "
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow_gan/python/estimator/tpu_gan_estimator.py:42: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow_gan/python/estimator/tpu_gan_estimator.py:42: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:Generating problems:
#     score2perf:
#       * score2perf_maestro_language_uncropped_aug
# I0101 21:39:34.559924 140173107692608 t2t_datagen.py:207] Generating problems:
#     score2perf:
#       * score2perf_maestro_language_uncropped_aug
# INFO:tensorflow:Generating data for score2perf_maestro_language_uncropped_aug.
# I0101 21:39:34.561072 140173107692608 t2t_datagen.py:280] Generating data for score2perf_maestro_language_uncropped_aug.
# I0101 21:39:34.591259 140173107692608 pipeline.py:188] Missing pipeline option (runner). Executing pipeline using the default runner: DirectRunner.
# W0101 21:39:35.092865 140173107692608 pipeline_options.py:336] Discarding unparseable args: ['']
# I0101 21:39:35.093341 140173107692608 environments.py:376] Default Python SDK image for environment is apache/beam_python3.7_sdk:2.40.0
# I0101 21:39:35.428336 140173107692608 translations.py:714] ==================== <function annotate_downstream_side_inputs at 0x7f7bf68b3320> ====================
# I0101 21:39:35.430051 140173107692608 translations.py:714] ==================== <function fix_side_input_pcoll_coders at 0x7f7bf68b3440> ====================
# I0101 21:39:35.431148 140173107692608 translations.py:714] ==================== <function pack_combiners at 0x7f7bf68b3950> ====================
# I0101 21:39:35.433125 140173107692608 translations.py:714] ==================== <function lift_combiners at 0x7f7bf68b39e0> ====================
# I0101 21:39:35.433556 140173107692608 translations.py:714] ==================== <function expand_sdf at 0x7f7bf68b3b90> ====================
# I0101 21:39:35.434226 140173107692608 translations.py:714] ==================== <function expand_gbk at 0x7f7bf68b3c20> ====================
# I0101 21:39:35.436103 140173107692608 translations.py:714] ==================== <function sink_flattens at 0x7f7bf68b3d40> ====================
# I0101 21:39:35.436632 140173107692608 translations.py:714] ==================== <function greedily_fuse at 0x7f7bf68b3dd0> ====================
# I0101 21:39:35.441239 140173107692608 translations.py:714] ==================== <function read_to_impulse at 0x7f7bf68b3e60> ====================
# I0101 21:39:35.441671 140173107692608 translations.py:714] ==================== <function impulse_to_input at 0x7f7bf68b3ef0> ====================
# I0101 21:39:35.442049 140173107692608 translations.py:714] ==================== <function sort_stages at 0x7f7bf68b4170> ====================
# I0101 21:39:35.443016 140173107692608 translations.py:714] ==================== <function add_impulse_to_dangling_transforms at 0x7f7bf68b4290> ====================
# I0101 21:39:35.443278 140173107692608 translations.py:714] ==================== <function setup_timer_mapping at 0x7f7bf68b40e0> ====================
# I0101 21:39:35.443902 140173107692608 translations.py:714] ==================== <function populate_data_channel_coders at 0x7f7bf68b4200> ====================
# I0101 21:39:35.459088 140173107692608 statecache.py:172] Creating state cache with size 100
# I0101 21:39:35.459789 140173107692608 worker_handlers.py:919] Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x7f7bf82da290> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# I0101 21:39:35.485576 140173107692608 auth.py:136] Setting socket default timeout to 60 seconds.
# I0101 21:39:35.485769 140173107692608 auth.py:139] socket default timeout is 60.0 seconds.
# W0101 21:39:38.494084 140173107692608 _metadata.py:104] Compute Engine Metadata server unavailable on attempt 1 of 3. Reason: timed out
# W0101 21:39:41.497544 140173107692608 _metadata.py:104] Compute Engine Metadata server unavailable on attempt 2 of 3. Reason: timed out
# W0101 21:39:44.501306 140173107692608 _metadata.py:104] Compute Engine Metadata server unavailable on attempt 3 of 3. Reason: timed out
# W0101 21:39:44.501567 140173107692608 _default.py:287] Authentication failed using Compute Engine authentication due to unavailable metadata server.
# W0101 21:39:44.501731 140173107692608 auth.py:168] Unable to find default credentials to use: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started
# Connecting anonymously.
# I0101 23:05:15.233545 140173107692608 filebasedsink.py:305] Starting finalize_write threads with num_shards: 1 (skipped: 0), batches: 1, num_threads: 1
# I0101 23:05:15.335577 140173107692608 filebasedsink.py:350] Renamed 1 shards in 0.10 seconds.
# I0101 23:05:15.509155 140173107692608 filebasedsink.py:305] Starting finalize_write threads with num_shards: 1 (skipped: 0), batches: 1, num_threads: 1
# I0101 23:05:15.610688 140173107692608 filebasedsink.py:350] Renamed 1 shards in 0.10 seconds.
# I0101 23:05:15.774693 140173107692608 filebasedsink.py:305] Starting finalize_write threads with num_shards: 1 (skipped: 0), batches: 1, num_threads: 1
# I0101 23:05:15.876042 140173107692608 filebasedsink.py:350] Renamed 1 shards in 0.10 seconds.

# %% [markdown]
# ## Training:

# %%
# !t2t_trainer \
--data_dir='./MagentaMusicTransformerData' \
--hparams="label_smoothing=0.0, max_length=0, max_target_seq_length=2048" \
--hparams_set=score2perf_transformer_base \
--model=transformer \
--output_dir='./MagentaMusicTransformerData/Training' \
--problem=score2perf_maestro_language_uncropped_aug \
--train_steps=25000 \
--alsologtostderr
# Out:
# /bin/bash: /home/ceo/anaconda3/envs/magenta/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/gym/utils/passive_env_checker.py:32: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (3, 3)
#   "A Box observation space has an unconventional shape (neither an image, nor a 1D vector). "
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow_gan/python/estimator/tpu_gan_estimator.py:42: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow_gan/python/estimator/tpu_gan_estimator.py:42: The name tf.estimator.tpu.TPUEstimator is deprecated. Please use tf.compat.v1.estimator.tpu.TPUEstimator instead.
#
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# INFO:tensorflow:Overriding hparams in score2perf_transformer_base with label_smoothing=0.0, max_length=0, max_target_seq_length=2048
# I0101 23:05:40.776604 139961361269824 hparams_lib.py:55] Overriding hparams in score2perf_transformer_base with label_smoothing=0.0, max_length=0, max_target_seq_length=2048
# INFO:tensorflow:Configuring DataParallelism to replicate the model.
# I0101 23:05:40.778469 139961361269824 trainer_lib.py:272] Configuring DataParallelism to replicate the model.
# INFO:tensorflow:schedule=continuous_train_and_eval
# I0101 23:05:40.778622 139961361269824 devices.py:76] schedule=continuous_train_and_eval
# INFO:tensorflow:worker_gpu=1
# I0101 23:05:40.778715 139961361269824 devices.py:77] worker_gpu=1
# INFO:tensorflow:sync=False
# I0101 23:05:40.778781 139961361269824 devices.py:78] sync=False
# WARNING:tensorflow:Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# W0101 23:05:40.778859 139961361269824 devices.py:141] Schedule=continuous_train_and_eval. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# I0101 23:05:40.779116 139961361269824 devices.py:170] datashard_devices: ['gpu:0']
# INFO:tensorflow:caching_devices: None
# I0101 23:05:40.779217 139961361269824 devices.py:171] caching_devices: None
# INFO:tensorflow:ps_devices: ['gpu:0']
# I0101 23:05:40.779321 139961361269824 devices.py:172] ps_devices: ['gpu:0']
# INFO:tensorflow:Using config: {'_model_dir': './MagentaMusicTransformerData/Training', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# isolate_session_state: true
# , '_keep_checkpoint_max': 20, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, 'use_tpu': False, 't2t_device_info': {'num_async_replicas': 1}, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f4ab5b0a250>}
# I0101 23:05:40.780666 139961361269824 estimator.py:202] Using config: {'_model_dir': './MagentaMusicTransformerData/Training', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.95
# }
# allow_soft_placement: true
# graph_options {
#   optimizer_options {
#     global_jit_level: OFF
#   }
# }
# isolate_session_state: true
# , '_keep_checkpoint_max': 20, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, 'use_tpu': False, 't2t_device_info': {'num_async_replicas': 1}, 'data_parallelism': <tensor2tensor.utils.expert_utils.Parallelism object at 0x7f4ab5b0a250>}
# WARNING:tensorflow:Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7f4aaf3e44d0>) includes params argument, but params are not passed to Estimator.
# W0101 23:05:40.781071 139961361269824 model_fn.py:626] Estimator's model_fn (<function T2TModel.make_estimator_model_fn.<locals>.wrapping_model_fn at 0x7f4aaf3e44d0>) includes params argument, but params are not passed to Estimator.
# WARNING:tensorflow:ValidationMonitor only works with --schedule=train_and_evaluate
# W0101 23:05:40.781277 139961361269824 trainer_lib.py:796] ValidationMonitor only works with --schedule=train_and_evaluate
# INFO:tensorflow:Not using Distribute Coordinator.
# I0101 23:05:40.803434 139961361269824 estimator_training.py:182] Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# I0101 23:05:40.803715 139961361269824 training.py:644] Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# I0101 23:05:40.803959 139961361269824 training.py:732] Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0101 23:05:40.815085 139961361269824 deprecation.py:356] From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/training/training_util.py:397: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-train*
# I0101 23:05:40.823104 139961361269824 problem.py:654] Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-train*
# INFO:tensorflow:partition: 0 num_data_files: 1
# I0101 23:05:40.836379 139961361269824 problem.py:680] partition: 0 num_data_files: 1
# WARNING:tensorflow:From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/data_generators/problem.py:690: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0101 23:05:40.838846 139961361269824 deprecation.py:356] From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/data_generators/problem.py:690: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/utils/data_reader.py:277: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0101 23:05:40.925128 139961361269824 deprecation.py:356] From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/utils/data_reader.py:277: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1082: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0101 23:05:42.880132 139961361269824 deprecation.py:356] From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1082: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/utils/data_reader.py:397: DatasetV1.output_shapes (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(dataset)`.
# W0101 23:05:42.884799 139961361269824 deprecation.py:356] From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/utils/data_reader.py:397: DatasetV1.output_shapes (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(dataset)`.
# WARNING:tensorflow:Shapes are not fully defined. Assuming batch_size means tokens.
# W0101 23:05:42.885046 139961361269824 data_reader.py:401] Shapes are not fully defined. Assuming batch_size means tokens.
# WARNING:tensorflow:From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/utils/data_reader.py:451: bucket_by_sequence_length (from tensorflow.python.data.experimental.ops.grouping) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.bucket_by_sequence_length(...)`.
# W0101 23:05:43.109789 139961361269824 deprecation.py:356] From /mnt/c/Users/colto/Documents/Programming/Repositories/experiments/plini_music_transformer/tensor2tensor/tensor2tensor/utils/data_reader.py:451: bucket_by_sequence_length (from tensorflow.python.data.experimental.ops.grouping) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.bucket_by_sequence_length(...)`.
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0101 23:05:43.537972 139961361269824 deprecation.py:356] From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Calling model_fn.
# I0101 23:05:43.697875 139961361269824 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'train'
# I0101 23:05:43.712769 139961361269824 t2t_model.py:2268] Setting T2TModel mode to 'train'
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# I0101 23:05:44.335603 139961361269824 api.py:459] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# I0101 23:05:49.202659 139961361269824 api.py:459] Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# INFO:tensorflow:Building model body
# I0101 23:05:49.962660 139961361269824 api.py:459] Building model body
# WARNING:tensorflow:From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0101 23:05:51.463463 139961361269824 deprecation.py:560] From /home/ceo/anaconda3/envs/magenta/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# INFO:tensorflow:Transforming body output with symbol_modality_310_512.top
# I0101 23:05:58.315929 139961361269824 api.py:459] Transforming body output with symbol_modality_310_512.top
# INFO:tensorflow:Base learning rate: 2.000000
# I0101 23:06:01.628978 139961361269824 learning_rate.py:29] Base learning rate: 2.000000
# INFO:tensorflow:Trainable Variables Total size: 19061760
# I0101 23:06:01.636159 139961361269824 optimize.py:355] Trainable Variables Total size: 19061760
# INFO:tensorflow:Non-trainable variables Total size: 5
# I0101 23:06:01.636502 139961361269824 optimize.py:355] Non-trainable variables Total size: 5
# INFO:tensorflow:Using optimizer adam
# I0101 23:06:01.636700 139961361269824 optimize.py:200] Using optimizer adam
# INFO:tensorflow:Done calling model_fn.
# I0101 23:06:03.632347 139961361269824 estimator.py:1175] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I0101 23:06:03.633512 139961361269824 basic_session_run_hooks.py:558] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# I0101 23:06:04.565879 139961361269824 monitored_session.py:243] Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# I0101 23:06:07.370354 139961361269824 session_manager.py:527] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0101 23:06:07.426323 139961361269824 session_manager.py:530] Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# I0101 23:06:09.703967 139961361269824 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into ./MagentaMusicTransformerData/Training/model.ckpt.
# I0101 23:06:09.711890 139961361269824 basic_session_run_hooks.py:633] Saving checkpoints for 0 into ./MagentaMusicTransformerData/Training/model.ckpt.
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-0.data-00000-of-00002
# I0101 23:06:11.210402 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-0.data-00000-of-00002
# INFO:tensorflow:0
# I0101 23:06:11.212360 139961361269824 saver.py:93] 0
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-0.data-00001-of-00002
# I0101 23:06:11.212540 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-0.data-00001-of-00002
# INFO:tensorflow:228700
# I0101 23:06:11.214391 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-0.index
# I0101 23:06:11.214586 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-0.index
# INFO:tensorflow:228700
# I0101 23:06:11.216005 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-0.meta
# I0101 23:06:11.216174 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-0.meta
# INFO:tensorflow:232300
# I0101 23:06:11.218327 139961361269824 saver.py:93] 232300
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# I0101 23:06:11.218722 139961361269824 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 9.46675, step = 0
# I0101 23:06:18.703903 139961361269824 basic_session_run_hooks.py:266] loss = 9.46675, step = 0
# INFO:tensorflow:global_step/sec: 2.96448
# I0101 23:06:52.429468 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 2.96448
# INFO:tensorflow:loss = 5.9406695, step = 100 (33.727 sec)
# I0101 23:06:52.430673 139961361269824 basic_session_run_hooks.py:264] loss = 5.9406695, step = 100 (33.727 sec)
# INFO:tensorflow:global_step/sec: 3.58475
# I0101 23:07:20.325017 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.58475
# INFO:tensorflow:loss = 5.1137624, step = 200 (27.895 sec)
# I0101 23:07:20.325577 139961361269824 basic_session_run_hooks.py:264] loss = 5.1137624, step = 200 (27.895 sec)
# INFO:tensorflow:global_step/sec: 3.55509
# I0101 23:07:48.453743 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.55509
# INFO:tensorflow:loss = 4.5540357, step = 300 (28.129 sec)
# I0101 23:07:48.454311 139961361269824 basic_session_run_hooks.py:264] loss = 4.5540357, step = 300 (28.129 sec)
# INFO:tensorflow:global_step/sec: 3.55558
# I0101 23:08:16.578578 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.55558
# INFO:tensorflow:loss = 4.658264, step = 400 (28.125 sec)
# I0101 23:08:16.579155 139961361269824 basic_session_run_hooks.py:264] loss = 4.658264, step = 400 (28.125 sec)
# INFO:tensorflow:global_step/sec: 3.52789
# I0101 23:08:44.924215 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.52789
# INFO:tensorflow:loss = 4.6044216, step = 500 (28.346 sec)
# I0101 23:08:44.924782 139961361269824 basic_session_run_hooks.py:264] loss = 4.6044216, step = 500 (28.346 sec)
# INFO:tensorflow:global_step/sec: 3.60075
# I0101 23:09:12.696160 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.60075
# INFO:tensorflow:loss = 4.5621395, step = 600 (27.772 sec)
# I0101 23:09:12.696734 139961361269824 basic_session_run_hooks.py:264] loss = 4.5621395, step = 600 (27.772 sec)
# INFO:tensorflow:global_step/sec: 3.59497
# I0101 23:09:40.512772 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.59497
# INFO:tensorflow:loss = 4.673415, step = 700 (27.817 sec)
# I0101 23:09:40.513458 139961361269824 basic_session_run_hooks.py:264] loss = 4.673415, step = 700 (27.817 sec)
# INFO:tensorflow:global_step/sec: 3.58541
# I0101 23:10:08.403591 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.58541
# INFO:tensorflow:loss = 4.006568, step = 800 (27.891 sec)
# I0101 23:10:08.404177 139961361269824 basic_session_run_hooks.py:264] loss = 4.006568, step = 800 (27.891 sec)
# INFO:tensorflow:global_step/sec: 3.56134
# I0101 23:10:36.482910 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.56134
# INFO:tensorflow:loss = 4.264827, step = 900 (28.079 sec)
# I0101 23:10:36.483504 139961361269824 basic_session_run_hooks.py:264] loss = 4.264827, step = 900 (28.079 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# I0101 23:11:04.298999 139961361269824 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# I0101 23:11:04.299419 139961361269824 basic_session_run_hooks.py:633] Saving checkpoints for 1000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-1000.data-00000-of-00002
# I0101 23:11:05.337884 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-1000.data-00000-of-00002
# INFO:tensorflow:0
# I0101 23:11:05.340164 139961361269824 saver.py:93] 0
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-1000.data-00001-of-00002
# I0101 23:11:05.340364 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-1000.data-00001-of-00002
# INFO:tensorflow:228700
# I0101 23:11:05.342096 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-1000.index
# I0101 23:11:05.342292 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-1000.index
# INFO:tensorflow:228700
# I0101 23:11:05.343886 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-1000.meta
# I0101 23:11:05.344086 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-1000.meta
# INFO:tensorflow:232300
# I0101 23:11:05.345596 139961361269824 saver.py:93] 232300
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# I0101 23:11:05.345921 139961361269824 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# I0101 23:11:05.362675 139961361269824 problem.py:654] Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# I0101 23:11:05.374859 139961361269824 problem.py:680] partition: 0 num_data_files: 1
# WARNING:tensorflow:Shapes are not fully defined. Assuming batch_size means tokens.
# W0101 23:11:05.431343 139961361269824 data_reader.py:401] Shapes are not fully defined. Assuming batch_size means tokens.
# INFO:tensorflow:Calling model_fn.
# I0101 23:11:05.511984 139961361269824 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# I0101 23:11:05.517961 139961361269824 t2t_model.py:2268] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.dropout to 0.0
# I0101 23:11:05.518263 139961361269824 t2t_model.py:2268] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# I0101 23:11:05.518347 139961361269824 t2t_model.py:2268] Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# I0101 23:11:05.518453 139961361269824 t2t_model.py:2268] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# I0101 23:11:05.518562 139961361269824 t2t_model.py:2268] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# I0101 23:11:05.518654 139961361269824 t2t_model.py:2268] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# I0101 23:11:05.518735 139961361269824 t2t_model.py:2268] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# I0101 23:11:05.567087 139961361269824 api.py:459] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# I0101 23:11:05.623501 139961361269824 api.py:459] Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# INFO:tensorflow:Building model body
# I0101 23:11:05.781086 139961361269824 api.py:459] Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_310_512.top
# I0101 23:11:07.966332 139961361269824 api.py:459] Transforming body output with symbol_modality_310_512.top
# INFO:tensorflow:Done calling model_fn.
# I0101 23:11:08.343648 139961361269824 estimator.py:1175] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-01-01T23:11:08
# I0101 23:11:08.357960 139961361269824 evaluation.py:251] Starting evaluation at 2023-01-01T23:11:08
# INFO:tensorflow:Graph was finalized.
# I0101 23:11:08.867932 139961361269824 monitored_session.py:243] Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-1000
# I0101 23:11:08.872480 139961361269824 saver.py:1412] Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# I0101 23:11:09.331518 139961361269824 session_manager.py:527] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0101 23:11:09.374927 139961361269824 session_manager.py:530] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0101 23:11:19.478430 139961361269824 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0101 23:11:29.278617 139961361269824 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0101 23:11:38.868850 139961361269824 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0101 23:11:48.458013 139961361269824 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0101 23:11:58.079439 139961361269824 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0101 23:12:07.274517 139961361269824 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0101 23:12:16.293281 139961361269824 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0101 23:12:25.475327 139961361269824 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0101 23:12:34.984786 139961361269824 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0101 23:12:44.206193 139961361269824 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 95.98695s
# I0101 23:12:44.345094 139961361269824 evaluation.py:269] Inference Time : 95.98695s
# INFO:tensorflow:Finished evaluation at 2023-01-01-23:12:44
# I0101 23:12:44.345545 139961361269824 evaluation.py:272] Finished evaluation at 2023-01-01-23:12:44
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 4.17097, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.08527064, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.24736793, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -4.1712704
# I0101 23:12:44.345748 139961361269824 estimator.py:2084] Saving dict for global step 1000: global_step = 1000, loss = 4.17097, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.08527064, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.24736793, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -4.1712704
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./MagentaMusicTransformerData/Training/model.ckpt-1000
# I0101 23:12:44.346687 139961361269824 estimator.py:2145] Saving 'checkpoint_path' summary for global step 1000: ./MagentaMusicTransformerData/Training/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.780406
# I0101 23:12:44.621372 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 0.780406
# INFO:tensorflow:loss = 4.2270865, step = 1000 (128.139 sec)
# I0101 23:12:44.622016 139961361269824 basic_session_run_hooks.py:264] loss = 4.2270865, step = 1000 (128.139 sec)
# INFO:tensorflow:global_step/sec: 3.56648
# I0101 23:13:12.660197 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.56648
# INFO:tensorflow:loss = 4.065574, step = 1100 (28.039 sec)
# I0101 23:13:12.660734 139961361269824 basic_session_run_hooks.py:264] loss = 4.065574, step = 1100 (28.039 sec)
# INFO:tensorflow:global_step/sec: 3.55698
# I0101 23:13:40.773938 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.55698
# INFO:tensorflow:loss = 4.266707, step = 1200 (28.114 sec)
# I0101 23:13:40.774391 139961361269824 basic_session_run_hooks.py:264] loss = 4.266707, step = 1200 (28.114 sec)
# INFO:tensorflow:global_step/sec: 3.54372
# I0101 23:14:08.992831 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.54372
# INFO:tensorflow:loss = 4.1965547, step = 1300 (28.219 sec)
# I0101 23:14:08.993289 139961361269824 basic_session_run_hooks.py:264] loss = 4.1965547, step = 1300 (28.219 sec)
# INFO:tensorflow:global_step/sec: 3.52802
# I0101 23:14:37.337347 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.52802
# INFO:tensorflow:loss = 4.451174, step = 1400 (28.345 sec)
# I0101 23:14:37.337805 139961361269824 basic_session_run_hooks.py:264] loss = 4.451174, step = 1400 (28.345 sec)
# INFO:tensorflow:global_step/sec: 3.50317
# I0101 23:15:05.882882 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.50317
# INFO:tensorflow:loss = 4.1687026, step = 1500 (28.546 sec)
# I0101 23:15:05.883322 139961361269824 basic_session_run_hooks.py:264] loss = 4.1687026, step = 1500 (28.546 sec)
# INFO:tensorflow:global_step/sec: 3.48662
# I0101 23:15:34.564029 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.48662
# INFO:tensorflow:loss = 3.9626775, step = 1600 (28.681 sec)
# I0101 23:15:34.564637 139961361269824 basic_session_run_hooks.py:264] loss = 3.9626775, step = 1600 (28.681 sec)
# INFO:tensorflow:global_step/sec: 3.48474
# I0101 23:16:03.260539 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.48474
# INFO:tensorflow:loss = 3.757012, step = 1700 (28.696 sec)
# I0101 23:16:03.260977 139961361269824 basic_session_run_hooks.py:264] loss = 3.757012, step = 1700 (28.696 sec)
# INFO:tensorflow:global_step/sec: 3.43986
# I0101 23:16:32.331449 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.43986
# INFO:tensorflow:loss = 3.97128, step = 1800 (29.071 sec)
# I0101 23:16:32.331809 139961361269824 basic_session_run_hooks.py:264] loss = 3.97128, step = 1800 (29.071 sec)
# INFO:tensorflow:global_step/sec: 3.44622
# I0101 23:17:01.348805 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.44622
# INFO:tensorflow:loss = 3.9286215, step = 1900 (29.017 sec)
# I0101 23:17:01.349240 139961361269824 basic_session_run_hooks.py:264] loss = 3.9286215, step = 1900 (29.017 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# I0101 23:17:30.043679 139961361269824 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# I0101 23:17:30.043936 139961361269824 basic_session_run_hooks.py:633] Saving checkpoints for 2000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-2000.data-00000-of-00002
# I0101 23:17:31.136362 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-2000.data-00000-of-00002
# INFO:tensorflow:0
# I0101 23:17:31.138253 139961361269824 saver.py:93] 0
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-2000.data-00001-of-00002
# I0101 23:17:31.138467 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-2000.data-00001-of-00002
# INFO:tensorflow:228700
# I0101 23:17:31.140134 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-2000.index
# I0101 23:17:31.140347 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-2000.index
# INFO:tensorflow:228700
# I0101 23:17:31.142031 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-2000.meta
# I0101 23:17:31.142221 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-2000.meta
# INFO:tensorflow:232300
# I0101 23:17:31.144324 139961361269824 saver.py:93] 232300
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# I0101 23:17:31.144803 139961361269824 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (600 secs).
# I0101 23:17:31.145009 139961361269824 training.py:560] Skip the current checkpoint eval due to throttle secs (600 secs).
# INFO:tensorflow:global_step/sec: 3.32535
# I0101 23:17:31.420835 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.32535
# INFO:tensorflow:loss = 3.8473787, step = 2000 (30.072 sec)
# I0101 23:17:31.421216 139961361269824 basic_session_run_hooks.py:264] loss = 3.8473787, step = 2000 (30.072 sec)
# INFO:tensorflow:global_step/sec: 3.44131
# I0101 23:18:00.479540 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.44131
# INFO:tensorflow:loss = 3.6998508, step = 2100 (29.059 sec)
# I0101 23:18:00.479954 139961361269824 basic_session_run_hooks.py:264] loss = 3.6998508, step = 2100 (29.059 sec)
# INFO:tensorflow:global_step/sec: 3.42863
# I0101 23:18:29.645728 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.42863
# INFO:tensorflow:loss = 3.6120124, step = 2200 (29.166 sec)
# I0101 23:18:29.646026 139961361269824 basic_session_run_hooks.py:264] loss = 3.6120124, step = 2200 (29.166 sec)
# INFO:tensorflow:global_step/sec: 3.41331
# I0101 23:18:58.942864 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.41331
# INFO:tensorflow:loss = 4.034914, step = 2300 (29.297 sec)
# I0101 23:18:58.943302 139961361269824 basic_session_run_hooks.py:264] loss = 4.034914, step = 2300 (29.297 sec)
# INFO:tensorflow:global_step/sec: 3.4141
# I0101 23:19:28.233193 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.4141
# INFO:tensorflow:loss = 3.7182589, step = 2400 (29.291 sec)
# I0101 23:19:28.234033 139961361269824 basic_session_run_hooks.py:264] loss = 3.7182589, step = 2400 (29.291 sec)
# INFO:tensorflow:global_step/sec: 3.42355
# I0101 23:19:57.442666 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.42355
# INFO:tensorflow:loss = 3.500776, step = 2500 (29.209 sec)
# I0101 23:19:57.443197 139961361269824 basic_session_run_hooks.py:264] loss = 3.500776, step = 2500 (29.209 sec)
# INFO:tensorflow:global_step/sec: 3.40062
# I0101 23:20:26.849079 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.40062
# INFO:tensorflow:loss = 3.3441339, step = 2600 (29.406 sec)
# I0101 23:20:26.849532 139961361269824 basic_session_run_hooks.py:264] loss = 3.3441339, step = 2600 (29.406 sec)
# INFO:tensorflow:global_step/sec: 3.40081
# I0101 23:20:56.253836 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.40081
# INFO:tensorflow:loss = 4.0009136, step = 2700 (29.405 sec)
# I0101 23:20:56.254434 139961361269824 basic_session_run_hooks.py:264] loss = 4.0009136, step = 2700 (29.405 sec)
# INFO:tensorflow:global_step/sec: 3.39536
# I0101 23:21:25.705837 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.39536
# INFO:tensorflow:loss = 3.8296082, step = 2800 (29.452 sec)
# I0101 23:21:25.706354 139961361269824 basic_session_run_hooks.py:264] loss = 3.8296082, step = 2800 (29.452 sec)
# INFO:tensorflow:global_step/sec: 3.4038
# I0101 23:21:55.084767 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.4038
# INFO:tensorflow:loss = 3.7718887, step = 2900 (29.379 sec)
# I0101 23:21:55.085191 139961361269824 basic_session_run_hooks.py:264] loss = 3.7718887, step = 2900 (29.379 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3000...
# I0101 23:22:24.103178 139961361269824 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 3000...
# INFO:tensorflow:Saving checkpoints for 3000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# I0101 23:22:24.103499 139961361269824 basic_session_run_hooks.py:633] Saving checkpoints for 3000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-3000.data-00000-of-00002
# I0101 23:22:25.118988 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-3000.data-00000-of-00002
# INFO:tensorflow:0
# I0101 23:22:25.120615 139961361269824 saver.py:93] 0
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-3000.data-00001-of-00002
# I0101 23:22:25.120762 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-3000.data-00001-of-00002
# INFO:tensorflow:228700
# I0101 23:22:25.122131 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-3000.index
# I0101 23:22:25.122212 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-3000.index
# INFO:tensorflow:228700
# I0101 23:22:25.123622 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-3000.meta
# I0101 23:22:25.123808 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-3000.meta
# INFO:tensorflow:232300
# I0101 23:22:25.125377 139961361269824 saver.py:93] 232300
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3000...
# I0101 23:22:25.125685 139961361269824 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 3000...
# INFO:tensorflow:Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# I0101 23:22:25.135692 139961361269824 problem.py:654] Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# I0101 23:22:25.143961 139961361269824 problem.py:680] partition: 0 num_data_files: 1
# WARNING:tensorflow:Shapes are not fully defined. Assuming batch_size means tokens.
# W0101 23:22:25.190498 139961361269824 data_reader.py:401] Shapes are not fully defined. Assuming batch_size means tokens.
# INFO:tensorflow:Calling model_fn.
# I0101 23:22:25.274744 139961361269824 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# I0101 23:22:25.281088 139961361269824 t2t_model.py:2268] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.dropout to 0.0
# I0101 23:22:25.281501 139961361269824 t2t_model.py:2268] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# I0101 23:22:25.281636 139961361269824 t2t_model.py:2268] Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# I0101 23:22:25.281763 139961361269824 t2t_model.py:2268] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# I0101 23:22:25.281883 139961361269824 t2t_model.py:2268] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# I0101 23:22:25.282010 139961361269824 t2t_model.py:2268] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# I0101 23:22:25.282125 139961361269824 t2t_model.py:2268] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# I0101 23:22:25.333542 139961361269824 api.py:459] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# I0101 23:22:25.384762 139961361269824 api.py:459] Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# INFO:tensorflow:Building model body
# I0101 23:22:25.528595 139961361269824 api.py:459] Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_310_512.top
# I0101 23:22:27.817440 139961361269824 api.py:459] Transforming body output with symbol_modality_310_512.top
# INFO:tensorflow:Done calling model_fn.
# I0101 23:22:28.531786 139961361269824 estimator.py:1175] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-01-01T23:22:28
# I0101 23:22:28.548457 139961361269824 evaluation.py:251] Starting evaluation at 2023-01-01T23:22:28
# INFO:tensorflow:Graph was finalized.
# I0101 23:22:28.712666 139961361269824 monitored_session.py:243] Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-3000
# I0101 23:22:28.715884 139961361269824 saver.py:1412] Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# I0101 23:22:29.271644 139961361269824 session_manager.py:527] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0101 23:22:29.330331 139961361269824 session_manager.py:530] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0101 23:22:41.330051 139961361269824 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0101 23:22:52.501797 139961361269824 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0101 23:23:03.472703 139961361269824 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0101 23:23:14.157098 139961361269824 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0101 23:23:25.106613 139961361269824 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0101 23:23:35.794264 139961361269824 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0101 23:23:46.066938 139961361269824 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0101 23:23:56.799022 139961361269824 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0101 23:24:07.827412 139961361269824 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0101 23:24:18.235059 139961361269824 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 109.83769s
# I0101 23:24:18.386356 139961361269824 evaluation.py:269] Inference Time : 109.83769s
# INFO:tensorflow:Finished evaluation at 2023-01-01-23:24:18
# I0101 23:24:18.387891 139961361269824 evaluation.py:272] Finished evaluation at 2023-01-01-23:24:18
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, loss = 3.6924005, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.108105354, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.3337609, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -3.6922507
# I0101 23:24:18.388136 139961361269824 estimator.py:2084] Saving dict for global step 3000: global_step = 3000, loss = 3.6924005, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.108105354, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.3337609, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -3.6922507
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: ./MagentaMusicTransformerData/Training/model.ckpt-3000
# I0101 23:24:18.389147 139961361269824 estimator.py:2145] Saving 'checkpoint_path' summary for global step 3000: ./MagentaMusicTransformerData/Training/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 0.696462
# I0101 23:24:18.667533 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 0.696462
# INFO:tensorflow:loss = 3.531333, step = 3000 (143.583 sec)
# I0101 23:24:18.668201 139961361269824 basic_session_run_hooks.py:264] loss = 3.531333, step = 3000 (143.583 sec)
# INFO:tensorflow:global_step/sec: 3.53022
# I0101 23:24:46.994447 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.53022
# INFO:tensorflow:loss = 3.454072, step = 3100 (28.327 sec)
# I0101 23:24:46.995512 139961361269824 basic_session_run_hooks.py:264] loss = 3.454072, step = 3100 (28.327 sec)
# INFO:tensorflow:global_step/sec: 3.45555
# I0101 23:25:15.933346 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.45555
# INFO:tensorflow:loss = 3.70243, step = 3200 (28.938 sec)
# I0101 23:25:15.933876 139961361269824 basic_session_run_hooks.py:264] loss = 3.70243, step = 3200 (28.938 sec)
# INFO:tensorflow:global_step/sec: 3.42976
# I0101 23:25:45.089908 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.42976
# INFO:tensorflow:loss = 3.7717094, step = 3300 (29.157 sec)
# I0101 23:25:45.091341 139961361269824 basic_session_run_hooks.py:264] loss = 3.7717094, step = 3300 (29.157 sec)
# INFO:tensorflow:global_step/sec: 3.36178
# I0101 23:26:14.836130 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.36178
# INFO:tensorflow:loss = 3.6382623, step = 3400 (29.745 sec)
# I0101 23:26:14.836694 139961361269824 basic_session_run_hooks.py:264] loss = 3.6382623, step = 3400 (29.745 sec)
# INFO:tensorflow:global_step/sec: 3.3954
# I0101 23:26:44.287666 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.3954
# INFO:tensorflow:loss = 3.6012928, step = 3500 (29.453 sec)
# I0101 23:26:44.289225 139961361269824 basic_session_run_hooks.py:264] loss = 3.6012928, step = 3500 (29.453 sec)
# INFO:tensorflow:global_step/sec: 3.37028
# I0101 23:27:13.958823 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.37028
# INFO:tensorflow:loss = 3.47129, step = 3600 (29.671 sec)
# I0101 23:27:13.959828 139961361269824 basic_session_run_hooks.py:264] loss = 3.47129, step = 3600 (29.671 sec)
# INFO:tensorflow:global_step/sec: 3.35657
# I0101 23:27:43.751171 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.35657
# INFO:tensorflow:loss = 3.5445266, step = 3700 (29.792 sec)
# I0101 23:27:43.752205 139961361269824 basic_session_run_hooks.py:264] loss = 3.5445266, step = 3700 (29.792 sec)
# INFO:tensorflow:global_step/sec: 3.37463
# I0101 23:28:13.383993 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.37463
# INFO:tensorflow:loss = 3.4513955, step = 3800 (29.633 sec)
# ...
# I0102 01:28:47.496468 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.38928
# INFO:tensorflow:loss = 2.419706, step = 24300 (29.505 sec)
# I0102 01:28:47.497184 139961361269824 basic_session_run_hooks.py:264] loss = 2.419706, step = 24300 (29.505 sec)
# INFO:tensorflow:global_step/sec: 3.38589
# I0102 01:29:17.030763 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.38589
# INFO:tensorflow:loss = 2.4502637, step = 24400 (29.534 sec)
# I0102 01:29:17.031238 139961361269824 basic_session_run_hooks.py:264] loss = 2.4502637, step = 24400 (29.534 sec)
# INFO:tensorflow:global_step/sec: 3.3776
# I0102 01:29:46.637614 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.3776
# INFO:tensorflow:loss = 2.1196117, step = 24500 (29.607 sec)
# I0102 01:29:46.638109 139961361269824 basic_session_run_hooks.py:264] loss = 2.1196117, step = 24500 (29.607 sec)
# INFO:tensorflow:global_step/sec: 3.33161
# I0102 01:30:16.653145 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.33161
# INFO:tensorflow:loss = 2.375723, step = 24600 (30.016 sec)
# I0102 01:30:16.653671 139961361269824 basic_session_run_hooks.py:264] loss = 2.375723, step = 24600 (30.016 sec)
# INFO:tensorflow:global_step/sec: 3.33291
# I0102 01:30:46.656946 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.33291
# INFO:tensorflow:loss = 2.2614725, step = 24700 (30.004 sec)
# I0102 01:30:46.657403 139961361269824 basic_session_run_hooks.py:264] loss = 2.2614725, step = 24700 (30.004 sec)
# INFO:tensorflow:global_step/sec: 3.36161
# I0102 01:31:16.404577 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.36161
# INFO:tensorflow:loss = 2.556183, step = 24800 (29.748 sec)
# I0102 01:31:16.404913 139961361269824 basic_session_run_hooks.py:264] loss = 2.556183, step = 24800 (29.748 sec)
# INFO:tensorflow:global_step/sec: 3.40214
# I0102 01:31:45.797769 139961361269824 basic_session_run_hooks.py:717] global_step/sec: 3.40214
# INFO:tensorflow:loss = 2.6696928, step = 24900 (29.393 sec)
# I0102 01:31:45.798218 139961361269824 basic_session_run_hooks.py:264] loss = 2.6696928, step = 24900 (29.393 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 25000...
# I0102 01:32:15.217018 139961361269824 basic_session_run_hooks.py:629] Calling checkpoint listeners before saving checkpoint 25000...
# INFO:tensorflow:Saving checkpoints for 25000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# I0102 01:32:15.217227 139961361269824 basic_session_run_hooks.py:633] Saving checkpoints for 25000 into ./MagentaMusicTransformerData/Training/model.ckpt.
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-25000.data-00000-of-00002
# I0102 01:32:16.298390 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-25000.data-00000-of-00002
# INFO:tensorflow:0
# I0102 01:32:16.300058 139961361269824 saver.py:93] 0
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-25000.data-00001-of-00002
# I0102 01:32:16.300233 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-25000.data-00001-of-00002
# INFO:tensorflow:228700
# I0102 01:32:16.301783 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-25000.index
# I0102 01:32:16.301978 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-25000.index
# INFO:tensorflow:228700
# I0102 01:32:16.304054 139961361269824 saver.py:93] 228700
# INFO:tensorflow:./MagentaMusicTransformerData/Training/model.ckpt-25000.meta
# I0102 01:32:16.304255 139961361269824 saver.py:90] ./MagentaMusicTransformerData/Training/model.ckpt-25000.meta
# INFO:tensorflow:232300
# I0102 01:32:16.305774 139961361269824 saver.py:93] 232300
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 25000...
# I0102 01:32:16.306070 139961361269824 basic_session_run_hooks.py:641] Calling checkpoint listeners after saving checkpoint 25000...
# INFO:tensorflow:Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# I0102 01:32:16.316803 139961361269824 problem.py:654] Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# I0102 01:32:16.326649 139961361269824 problem.py:680] partition: 0 num_data_files: 1
# WARNING:tensorflow:Shapes are not fully defined. Assuming batch_size means tokens.
# W0102 01:32:16.369589 139961361269824 data_reader.py:401] Shapes are not fully defined. Assuming batch_size means tokens.
# INFO:tensorflow:Calling model_fn.
# I0102 01:32:16.440553 139961361269824 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# I0102 01:32:16.446637 139961361269824 t2t_model.py:2268] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.dropout to 0.0
# I0102 01:32:16.446982 139961361269824 t2t_model.py:2268] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# I0102 01:32:16.447040 139961361269824 t2t_model.py:2268] Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# I0102 01:32:16.447082 139961361269824 t2t_model.py:2268] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# I0102 01:32:16.447161 139961361269824 t2t_model.py:2268] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# I0102 01:32:16.447252 139961361269824 t2t_model.py:2268] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# I0102 01:32:16.447360 139961361269824 t2t_model.py:2268] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# I0102 01:32:16.494549 139961361269824 api.py:459] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# I0102 01:32:16.541057 139961361269824 api.py:459] Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# INFO:tensorflow:Building model body
# I0102 01:32:16.679641 139961361269824 api.py:459] Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_310_512.top
# I0102 01:32:18.827788 139961361269824 api.py:459] Transforming body output with symbol_modality_310_512.top
# INFO:tensorflow:Done calling model_fn.
# I0102 01:32:19.201524 139961361269824 estimator.py:1175] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-01-02T01:32:19
# I0102 01:32:19.215965 139961361269824 evaluation.py:251] Starting evaluation at 2023-01-02T01:32:19
# INFO:tensorflow:Graph was finalized.
# I0102 01:32:19.381296 139961361269824 monitored_session.py:243] Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-25000
# I0102 01:32:19.383967 139961361269824 saver.py:1412] Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# I0102 01:32:19.826335 139961361269824 session_manager.py:527] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0102 01:32:19.874197 139961361269824 session_manager.py:530] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0102 01:32:31.239420 139961361269824 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0102 01:32:41.302782 139961361269824 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0102 01:32:51.086014 139961361269824 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0102 01:33:00.784913 139961361269824 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0102 01:33:11.653352 139961361269824 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0102 01:33:21.722144 139961361269824 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0102 01:33:32.121887 139961361269824 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0102 01:33:42.473577 139961361269824 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0102 01:33:53.801768 139961361269824 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0102 01:34:03.925844 139961361269824 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 104.84260s
# I0102 01:34:04.058757 139961361269824 evaluation.py:269] Inference Time : 104.84260s
# INFO:tensorflow:Finished evaluation at 2023-01-02-01:34:04
# I0102 01:34:04.059072 139961361269824 evaluation.py:272] Finished evaluation at 2023-01-02-01:34:04
# INFO:tensorflow:Saving dict for global step 25000: global_step = 25000, loss = 2.3764591, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.35142618, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.6795124, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -2.376407
# I0102 01:34:04.059204 139961361269824 estimator.py:2084] Saving dict for global step 25000: global_step = 25000, loss = 2.3764591, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.35142618, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.6795124, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -2.376407
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25000: ./MagentaMusicTransformerData/Training/model.ckpt-25000
# I0102 01:34:04.060137 139961361269824 estimator.py:2145] Saving 'checkpoint_path' summary for global step 25000: ./MagentaMusicTransformerData/Training/model.ckpt-25000
# INFO:tensorflow:Loss for final step: 2.4861343.
# I0102 01:34:04.192500 139961361269824 estimator.py:361] Loss for final step: 2.4861343.
# INFO:tensorflow:Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# I0102 01:34:04.211559 139961361269824 problem.py:654] Reading data files from ./MagentaMusicTransformerData/score2perf_maestro_language_uncropped_aug-dev*
# INFO:tensorflow:partition: 0 num_data_files: 1
# I0102 01:34:04.220750 139961361269824 problem.py:680] partition: 0 num_data_files: 1
# WARNING:tensorflow:Shapes are not fully defined. Assuming batch_size means tokens.
# W0102 01:34:04.268253 139961361269824 data_reader.py:401] Shapes are not fully defined. Assuming batch_size means tokens.
# INFO:tensorflow:Calling model_fn.
# I0102 01:34:04.344803 139961361269824 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Setting T2TModel mode to 'eval'
# I0102 01:34:04.351457 139961361269824 t2t_model.py:2268] Setting T2TModel mode to 'eval'
# INFO:tensorflow:Setting hparams.dropout to 0.0
# I0102 01:34:04.351794 139961361269824 t2t_model.py:2268] Setting hparams.dropout to 0.0
# INFO:tensorflow:Setting hparams.label_smoothing to 0.0
# I0102 01:34:04.351910 139961361269824 t2t_model.py:2268] Setting hparams.label_smoothing to 0.0
# INFO:tensorflow:Setting hparams.layer_prepostprocess_dropout to 0.0
# I0102 01:34:04.352031 139961361269824 t2t_model.py:2268] Setting hparams.layer_prepostprocess_dropout to 0.0
# INFO:tensorflow:Setting hparams.symbol_dropout to 0.0
# I0102 01:34:04.352122 139961361269824 t2t_model.py:2268] Setting hparams.symbol_dropout to 0.0
# INFO:tensorflow:Setting hparams.attention_dropout to 0.0
# I0102 01:34:04.352217 139961361269824 t2t_model.py:2268] Setting hparams.attention_dropout to 0.0
# INFO:tensorflow:Setting hparams.relu_dropout to 0.0
# I0102 01:34:04.352305 139961361269824 t2t_model.py:2268] Setting hparams.relu_dropout to 0.0
# INFO:tensorflow:Using variable initializer: uniform_unit_scaling
# I0102 01:34:04.401415 139961361269824 api.py:459] Using variable initializer: uniform_unit_scaling
# INFO:tensorflow:Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# I0102 01:34:04.454113 139961361269824 api.py:459] Transforming feature 'targets' with symbol_modality_310_512.targets_bottom
# INFO:tensorflow:Building model body
# I0102 01:34:04.601733 139961361269824 api.py:459] Building model body
# INFO:tensorflow:Transforming body output with symbol_modality_310_512.top
# I0102 01:34:06.887037 139961361269824 api.py:459] Transforming body output with symbol_modality_310_512.top
# INFO:tensorflow:Done calling model_fn.
# I0102 01:34:07.266710 139961361269824 estimator.py:1175] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-01-02T01:34:07
# I0102 01:34:07.280031 139961361269824 evaluation.py:251] Starting evaluation at 2023-01-02T01:34:07
# INFO:tensorflow:Graph was finalized.
# I0102 01:34:07.425235 139961361269824 monitored_session.py:243] Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-25000
# I0102 01:34:07.427827 139961361269824 saver.py:1412] Restoring parameters from ./MagentaMusicTransformerData/Training/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# I0102 01:34:07.904364 139961361269824 session_manager.py:527] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0102 01:34:07.948901 139961361269824 session_manager.py:530] Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# I0102 01:34:18.727925 139961361269824 evaluation.py:163] Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# I0102 01:34:28.955562 139961361269824 evaluation.py:163] Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# I0102 01:34:39.263387 139961361269824 evaluation.py:163] Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# I0102 01:34:49.622951 139961361269824 evaluation.py:163] Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# I0102 01:35:00.000928 139961361269824 evaluation.py:163] Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# I0102 01:35:10.252255 139961361269824 evaluation.py:163] Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# I0102 01:35:20.657210 139961361269824 evaluation.py:163] Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# I0102 01:35:31.061549 139961361269824 evaluation.py:163] Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# I0102 01:35:41.127237 139961361269824 evaluation.py:163] Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# I0102 01:35:51.672577 139961361269824 evaluation.py:163] Evaluation [100/100]
# INFO:tensorflow:Inference Time : 104.51879s
# I0102 01:35:51.799024 139961361269824 evaluation.py:269] Inference Time : 104.51879s
# INFO:tensorflow:Finished evaluation at 2023-01-02-01:35:51
# I0102 01:35:51.799339 139961361269824 evaluation.py:272] Finished evaluation at 2023-01-02-01:35:51
# INFO:tensorflow:Saving dict for global step 25000: global_step = 25000, loss = 2.3764591, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.35142618, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.6795124, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -2.3764067
# I0102 01:35:51.799468 139961361269824 estimator.py:2084] Saving dict for global step 25000: global_step = 25000, loss = 2.3764591, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy = 0.35142618, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_per_sequence = 0.0, metrics-score2perf_maestro_language_uncropped_aug/targets/accuracy_top5 = 0.6795124, metrics-score2perf_maestro_language_uncropped_aug/targets/neg_log_perplexity = -2.3764067
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25000: ./MagentaMusicTransformerData/Training/model.ckpt-25000
# I0102 01:35:52.177056 139961361269824 estimator.py:2145] Saving 'checkpoint_path' summary for global step 25000: ./MagentaMusicTransformerData/Training/model.ckpt-25000

# %% [markdown]
# ## Sampling:

# %%
# !t2t_decoder \
--data_dir='./MagentaMusicTransformerData' \
--decode_hparams="alpha=0, beam_size=1, extra_length=2048" \
--decode_interactive \
--hparams="sampling_method=random" \
--hparams_set=score2perf_transformer_base \
--model=transformer \
--problem=score2perf_maestro_language_uncropped_aug \
--output_dir='./MagentaMusicTransformerData/Generated'
