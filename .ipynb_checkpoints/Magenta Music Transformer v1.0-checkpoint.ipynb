# %% [markdown]
# ### Data generation / Preprocessing

# %%
# sudo apt-get install build-essential libasound2-dev libjack-dev portaudio19-dev
# sudo apt-get install libsndfile1
# !pip install magenta
# !pip install music21
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 6.0 MB/s eta 0:00:0000:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 1.0 MB/s eta 0:00:00-:--:--
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 8.6 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 8.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 8.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 8.9 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 8.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 2.6 MB/s eta 0:00:0000:0100:08
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 6.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
import magenta
import music21
import glob
import os
import sys

# %%
data_dir = './Magenta Music Transformer v1.0 Data'

# %%
for midi_file in glob.glob(data_dir + "/*.mid"):
    print(midi_file)
    try:
        midi = music21.converter.parse(midi_file)
        key = midi.analyze('key')
        if(key.mode == 'major'):
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('C'))
        elif(key.mode == 'minor'):
            i = music21.interval.Interval(key.tonic, music21.pitch.Pitch('A'))
        midi = midi.transpose(i)
        newKey = midi.analyze('key')
        print("Tranposed from: " + str(key) + " to " + str(newKey))
        midi.write('midi', fp=midi_file)
    except Exception as e:
        print("Transposing midi failed: " + str(e))
        continue;
# Out:
# ./Magenta Music Transformer v1.0 Data/01 Electric Sunrise GP.mid
# Tranposed from: C major to C major
# ./Magenta Music Transformer v1.0 Data/01 Heart GP.mid
# Tranposed from: a minor to a minor
# ./Magenta Music Transformer v1.0 Data/01 I'll Tell You Someday GP.mid
# Tranposed from: C major to C major
# ./Magenta Music Transformer v1.0 Data/01 Kind GP.mid
# Tranposed from: C major to C major
# ./Magenta Music Transformer v1.0 Data/01 Opening GP.mid
# Tranposed from: a minor to a minor
# ./Magenta Music Transformer v1.0 Data/01 The End of Everything GP.mid
# Tranposed from: e- minor to a minor
# ./Magenta Music Transformer v1.0 Data/02 Handmade Cities GP.mid
# Tranposed from: C major to C major
# ./Magenta Music Transformer v1.0 Data/02 Other Things GP.mid
# Tranposed from: a minor to a minor
# ./Magenta Music Transformer v1.0 Data/02 Papelillo GP.mid
# Tranposed from: a minor to a minor
# ./Magenta Music Transformer v1.0 Data/02 Salt   Charcoal GP.mid
# ...

# %%
magenta.tensor2tensor.t2t_datagen(data_dir=os.path.realpath(data_dir), problem='score2perf_maestro_language_uncropped_aug')
